# %%
# NOVÝ SPÔSOB – bez upozornenia
import vertexai
from vertexai.generative_models import GenerativeModel  # <-- bez .preview
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "gemini-key.json"
vertexai.init(project="bamboo-theorem-2000", location="us-central1")

model = GenerativeModel("gemini-2.0-flash")  # nový model

prompt = """
Príklad 1:
Vstup: "Ako zlepšiť produktivitu?"
Výstup: "Pracuj ako keby si mal 24 hodín na záchranu sveta."

Vstup: "Ako prekonať strach?"
Výstup:
"""

response = model.generate_content(prompt)
print("Gemini odpovedá:")
print(response.text)
# Out:
# Gemini odpovedá:
# "Urob to, čoho sa bojíš, a smrť strachu je istá."
