# %%
# Day 5: Test Vertex AI & Gemini 2.0 Flash

# !pip install google-cloud-aiplatform --quiet

import vertexai
from vertexai.generative_models import GenerativeModel
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "gemini-key.json"
vertexai.init(project="bamboo-theorem-2000", location="us-central1")
model = GenerativeModel("gemini-2.0-flash")

prompt = "Explain in 1 sentence: Who is a Prompt Engineer?"
response = model.generate_content(prompt)

print("Gemini Response:")
print(response.text)
print("\nSUCCESS: Vertex AI + Gemini is working!")
# Out:
# Gemini Response:
# A Prompt Engineer is someone who crafts effective prompts or instructions for AI models, particularly large language models, to elicit desired outputs and improve model performance for specific tasks.
#
#
# SUCCESS: Vertex AI + Gemini is working!
